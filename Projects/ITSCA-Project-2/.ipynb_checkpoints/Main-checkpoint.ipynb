# %%
#imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df_og = pd.read_csv('car_pricing_datasets.csv')  #import dataset

# %% [markdown]
# # Question 1
# *(25)*
#
# ## 1.1) Objective:
# Mutuka Automotive manually evaluates a large volume of second-hand vehicles to estimate their price. This wastes man-hours, is not scalable, and can be automated.
# First, we import the catalogue and check if the evaluation factors are present; an integrity check will be used for this. Then make a list of uncalculable vehicles and calculable vehicles by creating two new pandas arrays. We calculate the calculability by comparing the length of the arrays. We run the cost estimation function and compare that to manually estimated prices to find the error margin.
# A *successful solution* can parse the catalogue and estimate the value of vehicles or refer to manual evaluation if an anomaly is detected. More than 80% of vehicles should be able to be evaluated; calculability. Evaluation should be within a 10% error margin. *(5)*
#
# ## 1.2) Integrity Assesment:

# %%
# missing values
missing_count = df_og.isnull().sum()  # counts all missing per column
missing_count_pct = (missing_count / len(df_og)) * 100  # calculates missing percentage per column

print('\n', '-' * 50, '\n', ' ' * 15, 'Missing values:\n', '-' * 50)
print(missing_count)
print('\n', '-' * 50, '\n', ' ' * 12, 'Missing Percentage:\n', '-' * 50)
print(missing_count_pct)

missing_df = df_og[df_og.isnull().any(axis=1)].copy()  # makes data frame with all items with missing values
missing_pct = (len(missing_df) / len(df_og)) * 100  # calculates missing percentage total
df = df_og.dropna().copy()  # dataframe with missing values removed
# new dataframe for every question so I can reference old ones

print('\n', '-' * 50, '\n',
      '  Missing Row Percentage:',missing_pct,'%\n', '-' * 50)
# Out:
#  --------------------------------------------------
#                  Missing values:
#  --------------------------------------------------
# car_ID               9
# symboling            6
# CarName              7
# fueltype            10
# aspiration           2
# doornumber           7
# carbody             16
# drivewheel           4
# enginelocation       4
# wheelbase            5
# carlength           12
# carwidth             7
# carheight            3
# curbweight           7
# enginetype           2
# cylindernumber      10
# enginesize           9
# fuelsystem           6
# boreratio            7
# stroke               8
# compressionratio     6
# horsepower           5
# peakrpm              6
# citympg              8
# highwaympg          14
# price                0
# dtype: int64
#
#  --------------------------------------------------
#               Missing Percentage:
#  --------------------------------------------------
# car_ID              4.390244
# ...

# %%
# duplicate records
duplicate_count = df.duplicated().sum()  # counts all duplicated rows
duplicate_df = df[df.duplicated(keep=False)].copy()  # makes df with dupe rows
df = df.drop_duplicates() # drops row dupes
duplicate_pct = (len(duplicate_df) / len(df_og)) * 100  # calculates percentage of data that is dupelicated

print('\n', '-' * 50, '\n',
      ' ' * 16, 'Duplicate Rows:', duplicate_count, '\n',
      ' ' * 10, 'Duplicate Percentage:', duplicate_pct, '%\n',
      '-' * 50)
# Out:
#  --------------------------------------------------
#                   Duplicate Rows: 0
#             Duplicate Percentage: 0.0 %
#  --------------------------------------------------

# %%
# Inconsistent categories
print('\n', '-' * 50, '\n', ' ' * 15, 'Unique Check:\n', '-' * 50)
for col in df.select_dtypes(include='object').columns:  #find unique strings and their frequency
    print(f"\n{col}:")
    print(df[col].value_counts(dropna=False))
    print(df[col].unique())

# inconsistencies only found in CarName
df['make'] = df['CarName'].str.lower().str.strip().str.split().str[0] 
    #  makes lowercase     
    #  removes outer spaces
    #  extracts first word
df['make'] = df['make'].replace({'maxda': 'mazda', 'vokswagen': 'volkswagen', 'vw': 'volkswagen', 'porcshce': 'porsche'})  # add more as needed
    #  fixes spelling & inconcictency

print('\n', '-' * 50, '\n', ' ' * 15, 'Repared makes:\n', '-' * 50)
print(df['make'].value_counts(dropna=False))
print(df['make'].unique())
# Out:
#  --------------------------------------------------
#                  Unique Check:
#  --------------------------------------------------
#
# CarName:
# CarName
# peugeot 504         5
# toyota corolla      4
# toyota corona       4
# subaru dl           3
# honda civic         3
#                    ..
# mazda glc 4         1
# mazda rx2 coupe     1
# maxda glc deluxe    1
# maxda rx3           1
# volvo 246           1
# Name: count, Length: 127, dtype: int64
# ['alfa-romero giulia' 'alfa-romero stelvio' 'alfa-romero Quadrifoglio'
#  'audi 100 ls' 'audi 100ls' 'audi fox' 'audi 5000' 'audi 4000'
#  'audi 5000s (diesel)' 'bmw 320i' 'bmw x1' 'bmw z4' 'bmw x3'
#  'chevrolet monte carlo' 'chevrolet vega 2300' 'dodge rampage'
#  'dodge challenger se' 'dodge monaco (sw)' 'dodge colt hardtop'
#  'dodge colt (sw)' 'dodge coronet custom' 'dodge dart custom'
#  'dodge coronet custom (sw)' 'honda civic' 'honda civic cvcc'
#  'honda accord cvcc' 'honda civic 1500 gl' 'honda accord'
# ...

# %%
# unify data types
for col in df.columns:
    if col == 'CarName':  # skip car name
        continue
    if df[col].dtype == 'object':  # unify strings
        df[col] = df[col].astype(str).str.strip()
    elif pd.api.types.is_numeric_dtype(df[col]):  # unify numbers
        df[col] = pd.to_numeric(df[col], errors='coerce')

df.info()  # display uniform data types
df.describe(include='all')  # usefull info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 169 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            169 non-null    float64
#  1   symboling         169 non-null    float64
#  2   CarName           169 non-null    object
#  3   fueltype          169 non-null    object
#  4   aspiration        169 non-null    object
#  5   doornumber        169 non-null    object
#  6   carbody           169 non-null    object
#  7   drivewheel        169 non-null    object
#  8   enginelocation    169 non-null    object
#  9   wheelbase         169 non-null    float64
#  10  carlength         169 non-null    float64
#  11  carwidth          169 non-null    float64
#  12  carheight         169 non-null    float64
#  13  curbweight        169 non-null    float64
#  14  enginetype        169 non-null    object
#  15  cylindernumber    169 non-null    object
# ...

# %%
# Removing extreme values
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1  # inter quantile range
lower = Q1 - 1.5 * IQR  # lower limit
if lower < 0: lower = 0  # lower cant be below 0
upper = Q3 + 1.5 * IQR  # upper limit

extreme = df[(df['price'] < lower) | (df['price'] > upper)]

df = df[(df['price'] >= lower) & (df['price'] <= upper)].copy()
    # remove extreme prices

print('\n', '-' * 50, '\n', 
      len(extreme), ' rows removed between ', lower, ' and ', upper,
      '\n', '-' * 50)
extreme
# Out:
#  --------------------------------------------------
#  12  rows removed between  0  and  588900.0
#  --------------------------------------------------
#      car_ID  symboling                          CarName fueltype aspiration  \
# 17     18.0        0.0                           bmw x3      gas        std
# 47     48.0        0.0                        jaguar xj      gas        std
# 48     49.0        0.0                        jaguar xf      gas        std
# 49     50.0        0.0                        jaguar xk      gas        std
# 71     72.0       -1.0          buick opel isuzu deluxe      gas        std
# 72     73.0        3.0                    buick skylark      gas        std
# 73     74.0        0.0            buick century special      gas        std
# 74     75.0        1.0  buick regal sport coupe (turbo)      gas        std
# 126   127.0        3.0                porcshce panamera      gas        std
# ...

# %% [markdown]
# # 1.3) EDA:

# %%
# bulk data diplay
print('\n', '-' * 50, '\n', ' ' * 15, 'Array Description:\n', '-' * 50)
print(df.describe())
print('\n', '-' * 50, '\n', ' ' * 15, 'Categorical summaries:\n', '-' * 50)
for col in ['make', 'fueltype', 'carbody', 'drivewheel']:
    print(df[col].value_counts().head(10))

# price distribution
sns.histplot(df['price'], kde=True)  
plt.title('Price Distribution')
plt.show()

sns.heatmap(df.select_dtypes(include='number').corr(), annot=False, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
#  --------------------------------------------------
#                  Array Description:
#  --------------------------------------------------
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  157.000000  157.000000  157.000000  157.000000  157.000000  157.000000
# mean   101.796178    0.866242   98.245223  173.215924   65.685987   53.679618
# std     60.510938    1.214736    5.378035   11.326175    1.833046    2.505244
# min      1.000000   -2.000000   86.600000  144.600000   61.800000   48.800000
# 25%     51.000000    0.000000   94.500000  166.800000   64.000000   52.000000
# 50%    102.000000    1.000000   96.500000  173.000000   65.500000   54.100000
# 75%    155.000000    2.000000  100.400000  178.200000   66.500000   55.500000
# max    205.000000    3.000000  114.200000  198.900000   71.400000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# ...

# %% [markdown]
# ### Above charts indicate:
# Price Distribution: more expensive = less cars
#
# Correlation Heatmap:
# - Strong Correlation:
#   - Wheel Base
#   - Car Leangth
#   - Car Width
#   - Curb Weight
#   - Engine Size
#   - Horse Power
# - Inverse Correlation:
#   - City MPG
#   - Highway MPG
#
# Cost calculation prediction: Bigger cars are more expensive
#
# Potential Causal Chain:
# Long Wheel Base >> High Car Length >> High Car Width >> High Curb Weight >> High Horse Power >> High Engine Size >> Low City MPG >> Low Highway MPG
#
# Looking at this, we can make the following conclusions:
# - Bigger cars are more expensive
# - Cars with more power are more expensive

# %%
# price power drive
sns.scatterplot(x='horsepower', y='price', 
                hue='fueltype',
                size='enginesize', sizes=(20, 200), 
                style='aspiration', 
                data=df)
for fuel in ['gas', 'diesel']:
    subset = df[df['fueltype'] == fuel]
    sns.regplot(x='horsepower', y='price', data=subset, scatter=False, label=fuel)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title('Price to Engine')
plt.show()

# %% [markdown]
# - 4wd seems to have no correlation to price
# - fwd tents to have lower prices
# - rwd tends to have higher prices
# - diesel seems to be more expensive in ralation to their power; likely because their streangth is torque at low RPM
# - turbo cahrged engines increase power but not as much price

# %%
# price weight make
sns.scatterplot(x='curbweight', 
                y='price', 
                hue='make', 
                size='carwidth', sizes=(20, 200), 
                data=df)
sns.regplot(x='curbweight', y='price', data=df, scatter=False, color='magenta')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title('Price to Size and Manufacture')
plt.show()

# %% [markdown]
# - Curb weight corelates strongly until 2.5 Tonne then the corelation dies down
# - Make seems to lightly coralate with price especialy at higher prices
# - Horse Power increases as weight increases; less so with diesel

# %%
# price wheelbase bodystyle
sns.scatterplot(x='wheelbase', 
                y='price', 
                hue='carbody',
                style='drivewheel', 
                size='horsepower', sizes=(20, 200), 
                data=df)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title('Price to Character')
plt.show()

# %% [markdown]
# - RWD Hatches and Converables tend to break the correlation of wheel base to price; likely because they are considered sporty
# - RWD Wagons with a long wheel base seem to also break correlation; likely because they are concidered family cars

# %%
# extremes 
sns.scatterplot(x='horsepower', 
                y='price', 
                hue='make',
                size='curbweight', sizes=(20, 200), 
                data=extreme)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title('Extreme Values')
plt.show()

# %% [markdown]
# Display indicated removing extremes was the right choice

# %%
df['price_per_kg'] = df['price'] / df['curbweight']

plt.figure(figsize=(14, 6))
sns.violinplot(x='make', y='price_per_kg', data=df, order=df.groupby('make')['price_per_kg'].median().sort_values().index)
plt.xticks(rotation=45, ha='right')
plt.title('Price per KG per Manufacturer')
plt.show()

# %% [markdown]
# # Question 2¶
# *(25)*
#
# ## 2.1) Viecle Groups:
